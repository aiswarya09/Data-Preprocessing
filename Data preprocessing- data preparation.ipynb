# %% [markdown]
# # DATA PREPROCESSING/ DATA PREPARATION
# ### 3 Step Approach:
#
# **1. Data Cleaning: drop, dropna, Mean, median, mode imputation/ any value imputation for NaN values**
#
# **2. DataType Conversion**
#
# **3. Data Tranformation**

# %% [markdown]
# ## 1. Import Neccessary Libraries

# %%
import pandas as pd

# %% [markdown]
# ## 2. Import data

# %%
weather_data_2010 = pd.read_csv('data_clean.csv')
weather_data_2010
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %% [markdown]
# ## 3. Data Understanding

# %% [markdown]
# ### 3.1. Initial Analysis

# %%
weather_data_2010.shape
# Out:
# (158, 10)

# %%
weather_data_2010.isna().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
weather_data_2010.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %% [markdown]
# ## 4. Data Preparation:

# %% [markdown]
# ###  4.1. Data Cleaning:

# %%
weather_data_2010.drop(labels='Unnamed: 0', axis=1, inplace=True)

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      38
# Solar.R     7
# Wind        0
# Temp C      0
# Month       0
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
38/158*100
# Out:
# 24.050632911392405

# %% [markdown]
# #### Observation:
# We can see that there are a lot of null entries in the Ozone feature.
#
# **Que:**
#
# **1. What could be the reason for so many null values? - assumptions**
#
# **2. Should the null values in the column be replaced by mean/ median or should the null values be dropped completely? --GET THE CLIENTS APPROVAL.**

# %%
weather_data_2010['Ozone'].mean()
# Out:
# 41.583333333333336

# %%
weather_data_2010['Ozone'].median()
# Out:
# 30.5

# %% [markdown]
# ### Assumption: Client has approved to impute NaN values with median values for Ozone feature, drop NaN values for Solar.R and Weather features.

# %%
weather_data_2010['Ozone'].fillna(value=30.5, inplace=True)
##MEDIAN IMPUTATION

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
weather_data_2010.head(40)
# Out:
#     Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0    41.0    190.0   7.4     67     5    1  2010    67       S
# 1    36.0    118.0   8.0     72     5    2  2010    72       C
# 2    12.0    149.0  12.6     74     5    3  2010    74      PS
# 3    18.0    313.0  11.5     62     5    4  2010    62       S
# 4    30.5      NaN  14.3     56     5    5  2010    56       S
# 5    28.0      NaN  14.9     66     5    6  2010    66       C
# 6    23.0    299.0   8.6     65     5    7  2010    65      PS
# 7    19.0     99.0  13.8     59     5    8  2010    59       C
# 8     8.0     19.0  20.1     61     5    9  2010    61      PS
# 9    30.5    194.0   8.6     69     5   10  2010    69       S
# 10    7.0      NaN   6.9      C     5   11  2010    74       C
# 11   16.0    256.0   9.7     69     5   12  2010    69      PS
# 12   11.0    290.0   9.2     66     5   13  2010    66       S
# 13   14.0    274.0  10.9     68     5   14  2010    68       S
# ...

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
7/158*100
# Out:
# 4.430379746835443

# %% [markdown]
# #### Observation:
# There are very less observations with null values in Solar.R feature. It comprises of only 4% of the data. Hence, it can be dropped, but with client approval only.
#
# **Multiple feature imputation is never a good idea. It may lead to unreal data.**

# %%
weather_data_2010.dropna(inplace=True)

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp C     0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %% [markdown]
# ### 4.2 DataType conversion:

# %%
weather_data_2010.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Temp C      object
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
del weather_data_2010['Temp C']
#OR weather_data_2010.drop(labels='Temp C', axis=1, inplace=True)

# %%
weather_data_2010.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month       object
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_data_2010['Month'] = pd.to_numeric(weather_data_2010['Month'], errors='coerce') 
#### Any non numeric value gets converted to NaN. By default the numeric values get converted into float.

# %%
weather_data_2010.head(40)
# Out:
#     Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0    41.0    190.0   7.4    5.0    1  2010    67       S
# 1    36.0    118.0   8.0    5.0    2  2010    72       C
# 2    12.0    149.0  12.6    5.0    3  2010    74      PS
# 3    18.0    313.0  11.5    5.0    4  2010    62       S
# 6    23.0    299.0   8.6    5.0    7  2010    65      PS
# 7    19.0     99.0  13.8    5.0    8  2010    59       C
# 8     8.0     19.0  20.1    5.0    9  2010    61      PS
# 9    30.5    194.0   8.6    5.0   10  2010    69       S
# 11   16.0    256.0   9.7    5.0   12  2010    69      PS
# 12   11.0    290.0   9.2    5.0   13  2010    66       S
# 13   14.0    274.0  10.9    5.0   14  2010    68       S
# 14   18.0     65.0  13.2    5.0   15  2010    58       C
# 15   14.0    334.0  11.5    5.0   16  2010    64       S
# 16   34.0    307.0  12.0    5.0   17  2010    66       S
# 17    6.0     78.0  18.4    5.0   18  2010    57       C
# ...

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
weather_data_2010.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month      float64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_data_2010['Month'].fillna(value=5, inplace=True)

# %%
weather_data_2010.isna().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
weather_data_2010.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month      float64
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %%
weather_data_2010['Month'] = weather_data_2010['Month'].astype('int')

# %%
weather_data_2010.dtypes
# Out:
# Ozone      float64
# Solar.R    float64
# Wind       float64
# Month        int32
# Day          int64
# Year         int64
# Temp         int64
# Weather     object
# dtype: object

# %% [markdown]
# ### 4.3 Data tranformation:

# %%
weather_data_2010['Weather'].value_counts()
# Out:
# S     57
# C     46
# PS    46
# Name: Weather, dtype: int64

# %% [markdown]
# ### 2 Data Transformation Techniques: Discrete Vs Continuous
#
# **1. Dicrete - Label Encoding/ One Hot Encoding**
#
# **2 Continuous - MinMax Scaler/ Standard Scaler/ Robust Scaler**

# %% [markdown]
# ### 4.3.1  LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit_transform(weather_data_2010['Weather'])
# Out:
# array([2, 0, 1, 2, 1, 0, 1, 2, 1, 2, 2, 0, 2, 2, 0, 1, 2, 2, 0, 1, 0, 1,
#        0, 2, 2, 0, 1, 2, 0, 1, 0, 1, 0, 1, 2, 2, 2, 0, 1, 2, 2, 0, 1, 0,
#        1, 2, 2, 2, 0, 1, 2, 0, 1, 0, 1, 2, 2, 2, 0, 1, 2, 2, 0, 0, 1, 0,
#        1, 2, 2, 2, 0, 1, 2, 2, 0, 1, 0, 2, 2, 0, 1, 1, 0, 2, 0, 1, 0, 1,
#        1, 0, 1, 0, 1, 2, 2, 2, 0, 0, 0, 1, 0, 1, 2, 2, 0, 1, 0, 1, 2, 2,
#        2, 2, 2, 0, 0, 1, 0, 1, 2, 2, 2, 0, 1, 0, 1, 2, 2, 1, 1, 2, 1, 2,
#        0, 1, 1, 2, 2, 0, 1, 0, 1, 2, 1, 2, 0, 1, 2, 2, 0])

# %%
weather_data_2010_2 = weather_data_2010.copy()

# %%
weather_data_2010_2
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4      5    1  2010    67       S
# 1     36.0    118.0   8.0      5    2  2010    72       C
# 2     12.0    149.0  12.6      5    3  2010    74      PS
# 3     18.0    313.0  11.5      5    4  2010    62       S
# 6     23.0    299.0   8.6      5    7  2010    65      PS
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4      5    1  2010    67       C
# 154   30.0    193.0   6.9      9   26  2010    70      PS
# 155   30.5    145.0  13.2      9   27  2010    77       S
# 156   14.0    191.0  14.3      9   28  2010    75       S
# 157   18.0    131.0   8.0      9   29  2010    76       C
#
# [149 rows x 8 columns]

# %%
weather_data_2010_2['Weather'] = le.fit_transform(weather_data_2010['Weather'])

# %%
weather_data_2010_2
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp  Weather
# 0     41.0    190.0   7.4      5    1  2010    67        2
# 1     36.0    118.0   8.0      5    2  2010    72        0
# 2     12.0    149.0  12.6      5    3  2010    74        1
# 3     18.0    313.0  11.5      5    4  2010    62        2
# 6     23.0    299.0   8.6      5    7  2010    65        1
# ..     ...      ...   ...    ...  ...   ...   ...      ...
# 153   41.0    190.0   7.4      5    1  2010    67        0
# 154   30.0    193.0   6.9      9   26  2010    70        1
# 155   30.5    145.0  13.2      9   27  2010    77        2
# 156   14.0    191.0  14.3      9   28  2010    75        2
# 157   18.0    131.0   8.0      9   29  2010    76        0
#
# [149 rows x 8 columns]

# %% [markdown]
# ### 4.3.2 ONE HOT ENCODING
# It can be built using 2 libraries:
#
# **1. sklearn: OneHotEncoder()**
#
# **2. Pandas: pd.get_dummies()**

# %%
weather_data_2010_3 = weather_data_2010.copy()

# %% [markdown]
# #### SKLEARN

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(drop='first')
weather_data_2010_3['Weather'] = ohe.fit_transform(weather_data_2010_3['Weather'])
#ohe.fit_transform(weather_data_2010_3['Weather'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11552/1967122702.py in <module>
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 ohe = OneHotEncoder(drop='first')
# ----> 3 weather_data_2010_3['Weather'] = ohe.fit_transform(weather_data_2010_3['Weather'])
#       4 #ohe.fit_transform(weather_data_2010_3['Weather'])
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     449         """
#     450         self._validate_keywords()
# --> 451         return super().fit_transform(X, y)
#     452
#     453     def transform(self, X):
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
ohe_1 = pd.DataFrame(ohe.fit_transform(weather_data_2010_3['Weather']).toarray())

weather_data_2010_3 = weather_data_2010_3.join(ohe_1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11552/1555823065.py in <module>
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 ohe = OneHotEncoder()
# ----> 3 ohe_1 = pd.DataFrame(ohe.fit_transform(weather_data_2010_3['Weather']).toarray())
#       4
#       5 weather_data_2010_3 = weather_data_2010_3.join(ohe_1)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     449         """
#     450         self._validate_keywords()
# --> 451         return super().fit_transform(X, y)
#     452
#     453     def transform(self, X):
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# ...

# %%
import numpy as np

# %%
weather_data_2010_3.reshape(149,-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11552/3687717017.py in <module>
# ----> 1 weather_data_2010_3.reshape(149,-1)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
np.reshape(a=weather_data_2010_3, newshape = (149, -1))
# Out:
#      Ozone  Solar.R  Wind  Month   Day    Year  Temp  Weather_C  Weather_PS  \
# 0     41.0    190.0   7.4    5.0   1.0  2010.0  67.0        0.0         0.0
# 1     36.0    118.0   8.0    5.0   2.0  2010.0  72.0        1.0         0.0
# 2     12.0    149.0  12.6    5.0   3.0  2010.0  74.0        0.0         1.0
# 3     18.0    313.0  11.5    5.0   4.0  2010.0  62.0        0.0         0.0
# 6     23.0    299.0   8.6    5.0   7.0  2010.0  65.0        0.0         1.0
# ..     ...      ...   ...    ...   ...     ...   ...        ...         ...
# 153   41.0    190.0   7.4    5.0   1.0  2010.0  67.0        1.0         0.0
# 154   30.0    193.0   6.9    9.0  26.0  2010.0  70.0        0.0         1.0
# 155   30.5    145.0  13.2    9.0  27.0  2010.0  77.0        0.0         0.0
# 156   14.0    191.0  14.3    9.0  28.0  2010.0  75.0        0.0         0.0
# 157   18.0    131.0   8.0    9.0  29.0  2010.0  76.0        1.0         0.0
#
#      Weather_S
# 0          1.0
# 1          0.0
# ...

# %%
weather_data_2010_3['Weather'].ndim
# Out:
# 1

# %% [markdown]
# #### PANDAS

# %%
weather_data_2010_4 =pd.get_dummies(data = weather_data_2010,  columns= ['Weather'])
weather_data_2010_4
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp  Weather_C  Weather_PS  \
# 0     41.0    190.0   7.4      5    1  2010    67          0           0
# 1     36.0    118.0   8.0      5    2  2010    72          1           0
# 2     12.0    149.0  12.6      5    3  2010    74          0           1
# 3     18.0    313.0  11.5      5    4  2010    62          0           0
# 6     23.0    299.0   8.6      5    7  2010    65          0           1
# ..     ...      ...   ...    ...  ...   ...   ...        ...         ...
# 153   41.0    190.0   7.4      5    1  2010    67          1           0
# 154   30.0    193.0   6.9      9   26  2010    70          0           1
# 155   30.5    145.0  13.2      9   27  2010    77          0           0
# 156   14.0    191.0  14.3      9   28  2010    75          0           0
# 157   18.0    131.0   8.0      9   29  2010    76          1           0
#
#      Weather_S
# 0            1
# 1            0
# 2            0
# 3            1
# ...
